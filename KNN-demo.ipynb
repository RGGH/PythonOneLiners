# %% [markdown]
# ## K-Nearest-Neighbours

# %%
# visualize KNN

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

#set theme
sns.set_theme(style='darkgrid')

figure(figsize= (9, 9))
x = (X[:,0])
y = (X[:,1])

plt.title("2-D array")
plt.xlabel("sq metres")
plt.ylabel("house pice")

#create scatterplot
plt.scatter(x,y)
plt.show()

# %%
## KNN nearest neighbour

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
import numpy as np

# %%
## Data (House Size (square metres ) / House Price ($))
X = np.array([[35,30000],[45,45000],[40,50000],
             [35,35000],[25,32500],[40,40000]])

# %%
np.ndim(X)
# Out:
# 2

# %%
## One Liner 
KNN = KNeighborsRegressor(n_neighbors=3).fit(X[:,0].reshape(-1,1),X[:,1])
KNN
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
res = KNN.predict([[30]])
res
# Out:
# array([32500.])

# %%
# finds 3 closest houses with respect to house size ~ then averages the 3 nearest neighbours

# %%
print(X[:,0])
# Out:
# [35 45 40 35 25 40]
